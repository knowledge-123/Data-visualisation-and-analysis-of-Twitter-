# %% [markdown]
# # Twitter is one of the well-liked social media platforms where users can express themselves briefly. Twitter is well-liked, but not among investors. Examining Twitter's entire stock market history now that it is being delisted from the New York Stock Exchange will be helpful.

# %%
#The dataset contains data about:

# %%
#Date
#The opening Price of the day
#The highest price of the day
#The lowest price of the day
#The closing price of the day
#The adjusted closing price of the day
#The total number of shares traded in the day (volume)

# %%
import numpy as np 
import pandas as pd

# %%
#twitrAnalys = pd.read_csv('TWTR.csv')

# %%
twitrAnalys = pd.read_csv('TWTR.csv', index_col="Date",
                         parse_dates=True)

# %%
twitrAnalys.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2013-12-09  45.590000  49.840000  45.020000  49.139999  49.139999  17366614
# 2013-12-10  48.900002  52.580002  48.700001  51.990002  51.990002  25792002
# 2013-12-11  52.400002  53.869999  51.000000  52.340000  52.340000  26631535
# 2013-12-12  52.200001  55.869999  50.689999  55.330002  55.330002  23446870
# 2013-12-13  56.200001  59.410000  55.450001  59.000000  59.000000  38979567

# %%
twitrAnalys.tail()
# Out:
#            Open       High        Low      Close  Adj Close     Volume
# Date
# 2022  50.000000  50.750000  49.549999  49.889999  49.889999   51209029
# 2022  50.709999  51.860001  50.520000  51.520000  51.520000   22987553
# 2022  52.415001  53.180000  52.200001  52.779999  52.779999   35077848
# 2022  52.950001  53.500000  52.770000  53.349998  53.349998   28064973
# 2022  53.910000  54.000000  53.700001  53.700001  53.700001  136345128

# %%
twitrAnalys.shape
# Out:
# (2238, 6)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=twitrAnalys)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=twitrAnalys.index.year, y=twitrAnalys['Open'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=twitrAnalys.index.year, y=twitrAnalys['Close'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=twitrAnalys.index.year, y=twitrAnalys['Volume'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Volume'>

# %%
twit = twitrAnalys

# %%
twit.index = twit.index.year

# %%
twit
# Out:
#            Open       High        Low      Close  Adj Close     Volume
# Date
# 2013  45.590000  49.840000  45.020000  49.139999  49.139999   17366614
# 2013  48.900002  52.580002  48.700001  51.990002  51.990002   25792002
# 2013  52.400002  53.869999  51.000000  52.340000  52.340000   26631535
# 2013  52.200001  55.869999  50.689999  55.330002  55.330002   23446870
# 2013  56.200001  59.410000  55.450001  59.000000  59.000000   38979567
# ...         ...        ...        ...        ...        ...        ...
# 2022  50.000000  50.750000  49.549999  49.889999  49.889999   51209029
# 2022  50.709999  51.860001  50.520000  51.520000  51.520000   22987553
# 2022  52.415001  53.180000  52.200001  52.779999  52.779999   35077848
# 2022  52.950001  53.500000  52.770000  53.349998  53.349998   28064973
# 2022  53.910000  54.000000  53.700001  53.700001  53.700001  136345128
#
# [2238 rows x 6 columns]

# %%
twit.groupby('Date').Volume.mean()
# Out:
# Date
# 2013    3.338923e+07
# 2014    2.326785e+07
# 2015    2.120063e+07
# 2016    2.567749e+07
# 2017    1.752994e+07
# 2018    2.852057e+07
# 2019    1.542558e+07
# 2020    1.962157e+07
# 2021    1.682145e+07
# 2022    2.882022e+07
# Name: Volume, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=twitrAnalys, annot=True)
# Out:
# <AxesSubplot:ylabel='Date'>

# %%
sns.scatterplot(x=twitrAnalys['Open'], y=twitrAnalys['Close'])
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
sns.scatterplot(x=twitrAnalys['Open'], y=twitrAnalys['High'])
# Out:
# <AxesSubplot:xlabel='Open', ylabel='High'>

# %%
sns.scatterplot(x=twitrAnalys['Open'], y=twitrAnalys['Close'])
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
sns.scatterplot(x=twitrAnalys['Open'], y=twitrAnalys['Volume'])
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Volume'>

# %%
sns.regplot(x=twitrAnalys['Open'], y=twitrAnalys['Volume'])
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Volume'>

# %%
sns.scatterplot(x=twitrAnalys['Open'], y=twitrAnalys['Close'], hue=twitrAnalys.index)
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
# end #
